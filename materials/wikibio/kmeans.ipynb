# %% [markdown]
# # Virtual class example

# %%
import matplotlib.pyplot as plt

# %%
import pandas as pd
import numpy as np
from tqdm.notebook import tqdm

# %%
X = np.random.uniform(6, 10, (200, 2))

# %%
fig, ax = plt.subplots(figsize=(6, 6))
ax.scatter(X[:,0], X[:,1], alpha=0.6)
plt.tight_layout()
plt.show()

# %% [markdown]
# $$
# RSS = \sum\limits_{j=1}^{k}\sum\limits_{i=1}^{n} \delta(x_{i,k}, \mu_k)
# $$
